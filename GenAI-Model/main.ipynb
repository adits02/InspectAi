# %%
import google.generativeai as genai
from typing import List
import json
import time
import seaborn as sns
import pandas as pd
from google.api_core import exceptions

# %%
genai.configure(api_key="AIzaSyAogPEvYUJLJokjsV0oz1zl3_L81BKTcAY")
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
def load_jsonl_data(file_path):
    data = []
    with open(file_path, 'r') as f:
        for line in f:
            data.append(json.loads(line))
    return data

# %%
training_data = load_jsonl_data("sentiment_summary_qna.json")
base_model = "models/gemini-1.5-flash-001-tuning"

# %%
operation = genai.create_tuned_model(
    display_name = "Nirikshan-SahAI",
    source_model = base_model,
    epoch_count = 8,
    batch_size =3,
    learning_rate = 0.001,
    training_data = training_data,
    input_key = 'Q',
    output_key = 'A'
)
for status in operation.wait_bar():
    time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 operation = genai.create_tuned_model(
#       2     display_name = "Nirikshan-SahAI",
#       3     source_model = base_model,
#       4     epoch_count = 8,
#       5     batch_size =3,
#       6     learning_rate = 0.001,
#       7     training_data = training_data,
#       8     input_key = 'Q',
#       9     output_key = 'A'
#      10 )
#      11 for status in operation.wait_bar():
#      12     time.sleep(10)
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\generativeai\models.py:340, in create_tuned_model(source_model, training_data, id, display_name, description, temperature, top_p, top_k, epoch_count, batch_size, learning_rate, input_key, output_key, client, request_options)
#     335 else:
#     336     raise ValueError(
#     337         f"Invalid model name: The provided model '{source_model}' does not match any known model patterns such as 'models/' or 'tunedModels/'"
#     338     )
# --> 340 training_data = model_types.encode_tuning_data(
#     341     training_data, input_key=input_key, output_key=output_key
#     342 )
#     344 hyperparameters = protos.Hyperparameters(
#     345     epoch_count=epoch_count,
#     346     batch_size=batch_size,
#     347     learning_rate=learning_rate,
#     348 )
#     349 tuning_task = protos.TuningTask(
#     350     training_data=training_data,
#     351     hyperparameters=hyperparameters,
#     352 )
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\generativeai\types\model_types.py:267, in encode_tuning_data(data, input_key, output_key)
#     265     return _convert_dict(data, input_key, output_key)
#     266 else:
# --> 267     return _convert_iterable(data, input_key, output_key)
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\generativeai\types\model_types.py:315, in _convert_iterable(data, input_key, output_key)
#     313 new_data = list()
#     314 for example in data:
# --> 315     example = encode_tuning_example(example, input_key, output_key)
#     316     new_data.append(example)
#     317 return protos.Dataset(examples=protos.TuningExamples(examples=new_data))
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\google\generativeai\types\model_types.py:327, in encode_tuning_example(example, input_key, output_key)
#     325     example = protos.TuningExample(text_input=a, output=b)
#     326 else:  # dict
# --> 327     example = protos.TuningExample(text_input=example[input_key], output=example[output_key])
#     328 return example
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\proto\message.py:728, in Message.__init__(self, mapping, ignore_unknown_fields, **kwargs)
#     722         continue
#     724     raise ValueError(
#     725         "Unknown field for {}: {}".format(self.__class__.__name__, key)
#     726     )
# --> 728 pb_value = marshal.to_proto(pb_type, value)
#     730 if pb_value is not None:
#     731     params[key] = pb_value
#
# File c:\Users\sara_\AppData\Local\Programs\Python\Python311\Lib\site-packages\proto\marshal\marshal.py:229, in BaseMarshal.to_proto(self, proto_type, value, strict)
#     218         return type(value)(self.to_proto(proto_type, i) for i in value)
#     220 # Convert dictionaries recursively when the proto type is a map.
#     221 # This is slightly more complicated than converting a list or tuple
#     222 # because we have to step through the magic that protocol buffers does.
#    (...)
#     226 # annotation. We need to do the conversion based on the `value`
#     227 # field's type.
#     228 if isinstance(value, dict) and (
# --> 229     proto_type.DESCRIPTOR.has_options
#     230     and proto_type.DESCRIPTOR.GetOptions().map_entry
#     231 ):
#     232     recursive_type = type(proto_type().value)
#     233     return {k: self.to_proto(recursive_type, v) for k, v in value.items()}
#
# AttributeError: 'ProtoType' object has no attribute 'DESCRIPTOR'

# %%
result = operation.result()
print(result)

# %%
model = genai.GenerativeModel(model_name='tunedModels name')

# %%
snapshots = pd.DataFrame(result.tuning_task.snapshots)
sns.lineplot(data=snapshots, x='epoch', y='mean_loss')

# %%
def generate_response(prompt):
    model = genai.GenerativeModel(model_name = result.name)
    response = model.generate_content(prompt)
    return response.text

# %%
generate_response('text')
